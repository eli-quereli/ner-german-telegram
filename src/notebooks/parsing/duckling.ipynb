# %%
import pandas as pd
import sys
# adjust path
sys.path.append('../../../../NER-german-telegram')
# sys.path.append('/Library/Java/JavaVirtualMachines/jdk-18.0.1.1.jdk/Contents/Home/lib/libjli.dylib')

# %%
print(sys.path)
# Out:
# ['/Users/elisabeth/repos/NER-german-telegram/src/notebooks/parsing', '/Library/Frameworks/Python.framework/Versions/3.9/lib/python39.zip', '/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9', '/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/lib-dynload', '', '/Users/elisabeth/repos/NER-german-telegram/venv/lib/python3.9/site-packages', '../../../../NER-german-telegram', '../../../../NER-german-telegram', '../../../../NER-german-telegram', '/Library/Java/JavaVirtualMachines/jdk-18.0.1.1.jdk/Contents/Home/lib', '../../../../NER-german-telegram', '/Library/Java/JavaVirtualMachines/jdk-18.0.1.1.jdk/Contents/Home/lib/libjli.dylib', '../../../../NER-german-telegram', '/Library/Java/JavaVirtualMachines/jdk-18.0.1.1.jdk/Contents/Home/lib/libjli.dylib', '.']

# %%
sys.path.insert(0, os.path.abspath('..'))

# %%
file_name = '../temp/translations_2022_06_09-2.csv'

# %%
df = pd.read_csv(file_name, parse_dates=['date'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [73], in <cell line: 1>()
# ----> 1 df = pd.read_csv(file_name, parse_dates=['date'])
#
# File ~/repos/NER-german-telegram/venv/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.1  10 non-null     int64
#  1   Unnamed: 0    10 non-null     int64
#  2   id            10 non-null     object
#  3   message_id    10 non-null     int64
#  4   date          10 non-null     datetime64[ns]
#  5   cleaned_text  10 non-null     object
#  6   lang          10 non-null     object
#  7   text_length   10 non-null     int64
#  8   text_EN       10 non-null     object
#  9   text_DE       10 non-null     object
# dtypes: datetime64[ns](1), int64(4), object(5)
# memory usage: 928.0+ bytes

# %%
import os

# %%
path = '/Library/Java/JavaVirtualMachines/jdk-18.0.1.1.jdk/Contents/Home/lib/libjli.dylib'

# %%
os.path.exists(path)
# Out:
# True

# %%
import jpype

# %%
import jpype.imports

# %%
from jpype.types import *

# %%
jpype.startJVM()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [90], in <cell line: 1>()
# ----> 1 jpype.startJVM()
#
# File ~/repos/NER-german-telegram/venv/lib/python3.9/site-packages/jpype/_core.py:218, in startJVM(*args, **kwargs)
#     214     raise TypeError("startJVM() got an unexpected keyword argument '%s'"
#     215                     % (','.join([str(i) for i in kwargs])))
#     217 try:
# --> 218     _jpype.startup(jvmpath, tuple(args),
#     219                    ignoreUnrecognized, convertStrings, interrupt)
#     220     initializeResources()
#     221 except RuntimeError as ex:
#
# OSError: [Errno 0] JVM DLL not found: /Library/Java/JavaVirtualMachines/jdk-18.0.1.1.jdk/Contents/Home/lib/libjli.dylib

# %%
# %ls /Library/Java/JavaVirtualMachines/jdk-18.0.1.1.jdk/Contents/Home/lib/
# Out:
# classlist                  liblcms.dylib
# ct.sym                     libmanagement.dylib
# fontconfig.bfc             libmanagement_agent.dylib
# fontconfig.properties.src  libmanagement_ext.dylib
# jfr/                       libmlib_image.dylib
# jrt-fs.jar                 libnet.dylib
# jspawnhelper*              libnio.dylib
# jvm.cfg                    libosx.dylib
# libattach.dylib            libosxapp.dylib
# libawt.dylib               libosxkrb5.dylib
# libawt_lwawt.dylib         libosxsecurity.dylib
# libdt_socket.dylib         libosxui.dylib
# libextnet.dylib            libprefs.dylib
# libfontmanager.dylib       librmi.dylib
# libfreetype.dylib          libsaproc.dylib
# libinstrument.dylib        libsplashscreen.dylib
# libj2gss.dylib             libsyslookup.dylib
# libj2pcsc.dylib            libverify.dylib
# libj2pkcs11.dylib          libzip.dylib
# libjaas.dylib              modules
# libjava.dylib              psfont.properties.ja
# ...

# %%
jpype.getDefaultJVMPath()
# Out:
# '/Library/Java/JavaVirtualMachines/jdk-18.0.1.1.jdk/Contents/Home/lib/libjli.dylib'

# %%
jpype.getClassPath()
# Out:
# ''

# %%
from duckling import Duckling

# %%
d = Duckling()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [45], in <cell line: 1>()
# ----> 1 d = Duckling()
#
# File ~/repos/NER-german-telegram/venv/lib/python3.9/site-packages/duckling/duckling.py:44, in Duckling.__init__(self, jvm_started, parse_datetime, minimum_heap_size, maximum_heap_size)
#      42 if not jvm_started:
#      43     self._classpath = self._create_classpath()
# ---> 44     self._start_jvm(minimum_heap_size, maximum_heap_size)
#      46 try:
#      47     # make it thread-safe
#      48     if threading.activeCount() > 1:
#
# File ~/repos/NER-german-telegram/venv/lib/python3.9/site-packages/duckling/duckling.py:68, in Duckling._start_jvm(self, minimum_heap_size, maximum_heap_size)
#      61 jvm_options = [
#      62     '-Xms{minimum_heap_size}'.format(minimum_heap_size=minimum_heap_size),
# ...

# %%
# %cd /Library/Java/JavaVirtualMachines/jdk-18.0.1.1.jdk/Contents/Home/lib
# Out:
# /Library/Java/JavaVirtualMachines/jdk-18.0.1.1.jdk/Contents/Home/lib

# %%
# %ls /Library/Java/JavaVirtualMachines/jdk-18.0.1.1.jdk/Contents/Home/lib/libjli.dylib
# Out:
# /Library/Java/JavaVirtualMachines/jdk-18.0.1.1.jdk/Contents/Home/lib/libjli.dylib

# %%
% echo $JAVA_HOME
# Out:
# UsageError: Line magic function `%` not found.

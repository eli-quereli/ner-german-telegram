# %% [markdown]
# # Exploration of German-language Flair model for NER in Telegram messages

# %% [markdown]
# Using ten example texts selected from Telegram channels 'Demotermine' for first German-language NER experiments and for machine translation experiments.

# %%
import pandas as pd

file_name = '../../temp/translations_2022_06_09-2.csv'
data = pd.read_csv(file_name)
len(data)
# Out:
# 10

# %%
# Select cleaned texts as sample
texts = data.text_EN
texts[0]
# Out:
# 'Freiburg procession with final rally at the square of the old synagogue . Live music ! Details 19062021 Out on the street'

# %% [markdown]
# ## Predict and print entities in texts

# %%
from flair.models import SequenceTagger
from flair.data import Sentence

# Load Flair Sequence Tagger
tagger = SequenceTagger.load("flair/ner-english")


def get_entities(texts):
    
    for text in texts: 
        # transform example text to Sentence
        sentence = Sentence(text)

        # use tagger to predict NER tags in sentence
        tagger.predict(sentence)

        # print sentence
        print(sentence, '\n')

        # print predicted NER spans
        print('The following NER tags are found:')

        # iterate over entities and print
        for entity in sentence.get_spans('ner'):
            print(entity)
        print('\n\n')
# Out:
# 2022-07-23 14:12:14,471 loading file /Users/elisabeth/.flair/models/ner-english/4f4cdab26f24cb98b732b389e6cebc646c36f54cfd6e0b7d3b90b25656e4262f.8baa8ae8795f4df80b28e7f7b61d788ecbb057d1dc85aacb316f1bd02837a4a4
# 2022-07-23 14:12:17,795 SequenceTagger predicts: Dictionary with 20 tags: <unk>, O, S-ORG, S-MISC, B-PER, E-PER, S-LOC, B-ORG, E-ORG, I-PER, S-PER, B-MISC, I-MISC, E-MISC, I-ORG, B-LOC, E-LOC, I-LOC, <START>, <STOP>

# %%
get_entities(texts)
# Out:
# Sentence: "Freiburg procession with final rally at the square of the old synagogue . Live music ! Details 19062021 Out on the street" → ["Freiburg"/LOC]
#
# The following NER tags are found:
# Span[0:1]: "Freiburg" → LOC (0.997)
#
#
#
# Sentence: "GO DEMONSTRATE ! - Message from Elijah Tee to the Dresdeners & other demonstrators in Germany Tomorrow on 13.06 . at 16.30 clock and nationwide everywhere , where there are fellow thinkers . - Upload pictures and videos - discussion drive or ride along" → ["Elijah Tee"/PER, "Dresdeners"/MISC, "Germany"/LOC]
#
# The following NER tags are found:
# Span[6:8]: "Elijah Tee" → PER (0.9927)
# Span[10:11]: "Dresdeners" → MISC (0.4547)
# Span[15:16]: "Germany" → LOC (0.96)
#
#
#
# Sentence: "15831 Blankenfelde Mahlow Berlin Speckgürtel Lichtenrade exit on 03 / 14 / 2021 14032021 Out on the road" → ["Blankenfelde Mahlow Berlin Speckgürtel Lichtenrade"/MISC]
#
# The following NER tags are found:
# Span[1:6]: "Blankenfelde Mahlow Berlin Speckgürtel Lichtenrade" → MISC (0.6842)
#
#
#
# Sentence: "2021 10 11 Sven Liebich asks Prime Minister Haseloff about his understanding of assembly free - Sven Liebich 0:23 Raus auf die Straßen Overview / Overview" → ["Sven Liebich"/PER, "Haseloff"/PER, "Sven Liebich"/PER, "Raus auf die Straßen Overview"/ORG]
#
# The following NER tags are found:
# Span[3:5]: "Sven Liebich" → PER (0.9994)
# Span[8:9]: "Haseloff" → PER (0.9996)
# Span[16:18]: "Sven Liebich" → PER (0.9636)
# Span[19:24]: "Raus auf die Straßen Overview" → ORG (0.5787)
#
#
#
# Sentence: "FOR ALL DEMOCRATS DANGER : The police blocks the Stern ! That 's why people run from Ernst-Reuther-Platz to the southeast to Breitscheitplatz and there further to Kudamm ! ! Join : Neue Kantstraße directly to the east to Breitscheitplatz ! From the Straße des 17. Juni southwards to the Kudamm !" → ["Stern !"/MISC, "Ernst-Reuther-Platz"/LOC, "Breitscheitplatz"/LOC, "Kudamm"/LOC, "Neue Kantstraße"/ORG, "Breitscheitplatz"/LOC, "Straße des"/LOC, "Juni"/LOC, "Kudamm"/LOC]
#
# The following NER tags are found:
# Span[9:11]: "Stern !" → MISC (0.7695)
# Span[17:18]: "Ernst-Reuther-Platz" → LOC (0.9722)
# Span[22:23]: "Breitscheitplatz" → LOC (0.9985)
# Span[27:28]: "Kudamm" → LOC (0.4661)
# Span[32:34]: "Neue Kantstraße" → ORG (0.5343)
# Span[39:40]: "Breitscheitplatz" → LOC (0.8048)
# Span[43:45]: "Straße des" → LOC (0.901)
# Span[46:47]: "Juni" → LOC (0.9461)
# Span[50:51]: "Kudamm" → LOC (0.7052)
#
#
#
# Sentence: "Dr. Gunter Frank : How moralism leads to the fact that one sees enemies and wants to destroy - Antihygienista - Offene Gesellschaft Kurpfalz 15:04 Raus auf die Straßen Übersicht / Overview" → ["Gunter Frank"/PER]
#
# The following NER tags are found:
# Span[1:3]: "Gunter Frank" → PER (0.9307)
#
#
#
# Sentence: "Just sick such politicians ! What should we do with him if our children suffer from this vaccination ? Who is responsible for it , who do we throw in jail and take away all his money , shall we do that with you ? Out on the street"
#
# The following NER tags are found:
#
#
#
# Sentence: "27.11.2021 Frankfurt announcements of mixed with music . Super idea For more reports follow on ... Out on the streets Overview" → ["Frankfurt"/LOC]
#
# The following NER tags are found:
# Span[1:2]: "Frankfurt" → LOC (0.9701)
#
#
#
# Sentence: "Demo-Berlin : The man with the sign has just been arrested by the police . About 7 emergency vehicles are on site and fence the park extensively . At the Humboldthain there is nothing more to win . # b2908 Out on the streets" → ["Humboldthain"/LOC]
#
# The following NER tags are found:
# Span[30:31]: "Humboldthain" → LOC (0.7358)
#
#
#
# Sentence: "Anthony Fauci : Definition of " fully vaccinated " could be changed - Epoch Times News 6:59 Out on the Streets Overview / Overview ." → ["Anthony Fauci"/PER, "Epoch Times News"/ORG, "Streets Overview"/MISC]
#
# The following NER tags are found:
# Span[0:2]: "Anthony Fauci" → PER (0.9907)
# Span[13:16]: "Epoch Times News" → ORG (0.7133)
# Span[20:22]: "Streets Overview" → MISC (0.8121)

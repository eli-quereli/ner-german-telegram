# %%
from transformers import pipeline

classifier = pipeline('ner', model="fhswf/bert_de_ner")
classifier('Von der Organisation „medico international“ hieß es, die EU entziehe sich seit vielen Jahren der Verantwortung für die Menschen an ihren Außengrenzen.')
# Out:
# Downloading:   0%|          | 0.00/1.50k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/419M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/62.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/234k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# [{'entity': 'B-ORG',
#   'score': 0.99966204,
#   'index': 6,
#   'word': 'med',
#   'start': 22,
#   'end': 25},
#  {'entity': 'I-ORG',
#   'score': 0.9995363,
#   'index': 7,
#   'word': '##ico',
#   'start': 25,
#   'end': 28},
#  {'entity': 'I-ORG',
#   'score': 0.9996933,
#   'index': 8,
#   'word': 'international',
#   'start': 29,
#   'end': 42},
#  {'entity': 'B-ORG',
#   'score': 0.999701,
#   'index': 14,
#   'word': 'eu',
#   'start': 57,
#   'end': 59}]

# %%
import pandas as pd
df = pd.read_csv('../temp/translations_2022_06_09-2.csv')

# %%
for text in df.text_EN.values:
    
    print(text)
    ner_result = classifier(text)
    
    for i in range(len(ner_result)):
        print(ner_result[i])
        #for key in ner_result[i].keys():
            #print(ner_result[i][key])
#        print(ner_result[i])
# Out:
# Freiburg procession with final rally at the square of the old synagogue . Live music ! Details 19062021 Out on the street
# {'entity': 'B-LOC', 'score': 0.9997844, 'index': 1, 'word': 'frei', 'start': 0, 'end': 4}
# {'entity': 'I-LOC', 'score': 0.91726744, 'index': 2, 'word': '##burg', 'start': 4, 'end': 8}
# {'entity': 'I-OTH', 'score': 0.7982835, 'index': 18, 'word': 'the', 'start': 54, 'end': 57}
# {'entity': 'I-OTH', 'score': 0.9656933, 'index': 19, 'word': 'ol', 'start': 58, 'end': 60}
# {'entity': 'I-OTH', 'score': 0.9607531, 'index': 20, 'word': '##d', 'start': 60, 'end': 61}
# {'entity': 'I-OTH', 'score': 0.94191664, 'index': 21, 'word': 'syn', 'start': 62, 'end': 65}
# {'entity': 'I-OTH', 'score': 0.94786465, 'index': 22, 'word': '##ago', 'start': 65, 'end': 68}
# {'entity': 'I-OTH', 'score': 0.9159916, 'index': 23, 'word': '##gu', 'start': 68, 'end': 70}
# {'entity': 'I-OTH', 'score': 0.89391106, 'index': 24, 'word': '##e', 'start': 70, 'end': 71}
# ...

# %%
for text in df.text_DE.values:
    
    print(text)
    ner_result = classifier(text)
    print(ner_result)
# Out:
# Freiburger Prozession mit Abschlusskundgebung auf dem Platz der alten Synagoge. Live Musik ! Details 19062021 Draußen auf der Straße
# [{'entity': 'B-LOCderiv', 'score': 0.99864644, 'index': 1, 'word': 'frei', 'start': 0, 'end': 4}, {'entity': 'B-LOCderiv', 'score': 0.9958819, 'index': 2, 'word': '##burger', 'start': 4, 'end': 10}, {'entity': 'I-LOC', 'score': 0.6882809, 'index': 15, 'word': 'syn', 'start': 70, 'end': 73}]
# GEHT DEMONSTRIEREN ! - Botschaft von Elijah Tee an die Dresdner & andere Demonstranten in Deutschland Morgen am 13.06. um 16.30 Uhr und bundesweit überall, wo es Mitdenker gibt. - Bilder und Videos hochladen - Diskussion fahren oder mitfahren
# ...

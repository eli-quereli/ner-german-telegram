# %% [markdown]
# ## imports

# %%
import sys
sys.path.append('../../../NER-german-telegram')

import pandas as pd
from datetime import datetime
from random import sample

import spacy
from spacy import displacy

# %% [markdown]
# ## load data

# %%
file_name = '../../temp/translations_2022_06_09-2.csv'

# %%
data = pd.read_csv(file_name)

# %%
df = data[['id', 'cleaned_text', 'text_EN']]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            10 non-null     object
#  1   cleaned_text  10 non-null     object
#  2   text_EN       10 non-null     object
# dtypes: object(3)
# memory usage: 368.0+ bytes

# %% [markdown]
# ## select some sample texts

# %%
samples = df.text_EN.values

# %%
samples
# Out:
# array(['Freiburg procession with final rally at the square of the old synagogue . Live music ! Details 19062021 Out on the street',
#        'GO DEMONSTRATE ! - Message from Elijah Tee to the Dresdeners & other demonstrators in Germany Tomorrow on 13.06. at 16.30 clock and nationwide everywhere , where there are fellow thinkers . - Upload pictures and videos - discussion drive or ride along',
#        '15831 Blankenfelde Mahlow Berlin Speckgürtel Lichtenrade exit on 03/14/2021 14032021 Out on the road',
#        '2021 10 11 Sven Liebich asks Prime Minister Haseloff about his understanding of assembly free - Sven Liebich 0:23 Raus auf die Straßen Overview / Overview',
#        "  FOR ALL DEMOCRATS DANGER : The police blocks the Stern !   That's why people run from Ernst-Reuther-Platz to the southeast to Breitscheitplatz and there further to Kudamm ! ! Join : Neue Kantstraße directly to the east to Breitscheitplatz ! From the Straße des 17. Juni southwards to the Kudamm !",
#        'Dr. Gunter Frank : How moralism leads to the fact that one sees enemies and wants to destroy - Antihygienista - Offene Gesellschaft Kurpfalz 15:04 Raus auf die Straßen Übersicht / Overview',
#        'Just sick such politicians ! What should we do with him if our children suffer from this vaccination? Who is responsible for it, who do we throw in jail and take away all his money, shall we do that with you? Out on the street',
#        '27.11.2021 Frankfurt announcements of mixed with music . Super idea For more reports follow on ... Out on the streets Overview',
#        '  Demo-Berlin : The man with the sign has just been arrested by the police . About 7 emergency vehicles are on site and fence the park extensively . At the Humboldthain there is nothing more to win . # b2908 Out on the streets',
#        'Anthony Fauci : Definition of " fully vaccinated " could be changed - Epoch Times News 6:59 Out on the Streets Overview / Overview.'],
#       dtype=object)

# %% [markdown]
# # Spacy

# %% [markdown]
# ## load model

# %%
nlp = spacy.load("en_core_web_trf")

# %%
def get_entities(texts): 

    for text in texts: 
        
        entities = {}
        
        try: 
            doc = nlp(text)
            
            if doc.ents:
                print([(ent.text, ent.label_) for ent in doc.ents])
    
        except: 
            pass

# %%
def display_entities(texts):
    
    for text in texts: 
    
        try: 
            doc = nlp(text)
            sentence_spans = list(doc.sents)
            displacy.render(sentence_spans, style="ent")

        except:
            pass

# %%
get_entities(samples)
# Out:
# [('Germany', 'GPE'), ('Tomorrow', 'DATE'), ('13.06', 'CARDINAL'), ('16.30', 'CARDINAL')]
# [('15831', 'DATE'), ('Blankenfelde Mahlow Berlin', 'PERSON'), ('Speckgürtel Lichtenrade', 'PERSON'), ('03/14/2021 14032021', 'DATE')]
# [('Sven Liebich', 'ORG'), ('Haseloff', 'PERSON'), ('Straßen Overview / Overview', 'ORG')]
# [('DEMOCRATS', 'NORP'), ('Ernst-Reuther-Platz', 'ORG'), ('Breitscheitplatz', 'PERSON'), ('Kudamm', 'FAC'), ('Neue Kantstraße', 'PERSON'), ('Straße', 'GPE'), ('17', 'CARDINAL'), ('Kudamm', 'FAC')]
# [('Gunter Frank', 'PERSON'), ('15:04 Raus auf', 'PERSON'), ('Straßen Übersicht / Overview', 'ORG')]
# [('Frankfurt', 'GPE')]
# [('Humboldthain', 'PERSON'), ('#', 'CARDINAL')]
# [('Anthony Fauci', 'PERSON'), ('the Streets Overview / Overview', 'ORG')]

# %%
display_entities(samples)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Freiburg procession with final rally at the square of the old synagogue . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Live music ! </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Details 19062021 Out on the street</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">GO DEMONSTRATE ! </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">- Message from Elijah Tee to the Dresdeners &amp; other demonstrators in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Germany
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tomorrow
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  on
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     13.06
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">at
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     16.30
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  clock and nationwide everywhere , where there are fellow thinkers . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">- Upload pictures and videos - discussion drive or ride along</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     15831
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Blankenfelde Mahlow Berlin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Speckgürtel Lichtenrade
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  exit on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     03/14/2021 14032021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  Out on the road</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">2021 10 11
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sven Liebich
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  asks Prime Minister
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Haseloff
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  about his understanding of assembly free - Sven Liebich 0:23 </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Raus auf die
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Straßen Overview / Overview
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">  FOR ALL
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DEMOCRATS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  DANGER : </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">The police blocks the Stern ! </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">  </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">That's why people run from
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ernst-Reuther-Platz
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  to the southeast to
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Breitscheitplatz
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and there further to
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kudamm
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#  ! ! </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Join :
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Neue Kantstraße
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  directly to the east to Breitscheitplatz ! </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">From the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Straße
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  des
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     17
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Juni southwards to the
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kudamm
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#  !</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Dr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gunter Frank
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  : How moralism leads to the fact that one sees enemies and wants to destroy - Antihygienista - Offene Gesellschaft Kurpfalz
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     15:04 Raus auf
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  die
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Straßen Übersicht / Overview
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Just sick such politicians ! </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">What should we do with him if our children suffer from this vaccination? </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Who is responsible for it, who do we throw in jail and take away all his money, shall we do that with you? </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Out on the street</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">27.11.2021
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Frankfurt
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  announcements of mixed with music . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Super idea For more reports follow on ... </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Out on the streets Overview</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">  Demo-Berlin : The man with the sign has just been arrested by the police . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">About 7 emergency vehicles are on site and fence the park extensively . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">At the
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Humboldthain
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  there is nothing more to win . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     #
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  b2908 </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Out on the streets</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Anthony Fauci
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  : Definition of &quot; fully vaccinated &quot; could be changed - Epoch Times News 6:59 Out on
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Streets Overview / Overview
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .</div></span>

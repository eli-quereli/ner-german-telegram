# %% [markdown]
# # Exploration of medium-size German-language spaCy model for NER in Telegram messages

# %% [markdown]
# ## Imports

# %%
import sys
sys.path.append('../../../NER-german-telegram')

import pandas as pd
from datetime import datetime
from random import sample

import spacy
from spacy import displacy

# %% [markdown]
# ## Load data

# %% [markdown]
# Using 10 example texts selected from Telegram channels 'Demotermine' for first German-language NER experiments and for machine translation experiments.

# %%
file_name = '../../temp/translations_2022_06_09-2.csv'
data = pd.read_csv(file_name)

# %%
len(data)
# Out:
# 10

# %% [markdown]
# ## Select cleaned texts as sample

# %%
samples = df.cleaned_text
samples[0]
# Out:
# 'Freiburg Aufzug mit Endkundgebung am Platz der alten Synagoge . Live Musik ! Details 19062021 Raus auf die Straße'

# %% [markdown]
# ## Load German-language medium-size spaCy model

# %%
nlp = spacy.load("de_core_news_md")

# %% [markdown]
# ## Methods to obtain and display entities in texts

# %%
def get_entities(texts): 

    for text in texts: 
        
        entities = {}
        
        try: 
            doc = nlp(text)
            
            if doc.ents:
                print([(ent.text, ent.label_, ent.) for ent in doc.ents])
    
        except: 
            pass

# %%
def display_entities(texts):
    
    for text in texts: 
    
        try: 
            doc = nlp(text)
            sentence_spans = list(doc.sents)
            displacy.render(sentence_spans, style="ent")
            print('\n\n++++++++++++\n\n')

        except:
            pass

# %% [markdown]
# ## Execute

# %%
get_entities(samples)
# Out:
# [('Endkundgebung', 'LOC'), ('alten Synagoge', 'LOC')]
# [('GEHT DEMONSTRIEREN', 'ORG'), ('Elijah Tee', 'PER'), ('Dresdner &', 'LOC'), ('Deutschland', 'LOC'), ('Videos', 'MISC')]
# [('Blankenfelde Mahlow', 'PER'), ('Berliner', 'MISC')]
# [('Sven Liebich', 'PER'), ('Haseloff', 'PER'), ('Versammlungsfre', 'PER'), ('Sven Liebich', 'PER')]
# [('DEMOKRATEN', 'ORG'), ('Ernst-Reuther-Platz', 'LOC'), ('Breitscheitplatz', 'LOC'), ('Kudamm ! !', 'LOC'), ('Neue Kantstraße', 'LOC'), ('Breitscheitplatz', 'LOC'), ('Kudamm !', 'LOC')]
# [('Gunter Frank', 'PER'), ('Antihygienista', 'LOC'), ('Offene Gesellschaft Kurpfalz', 'ORG')]
# [('Einfach', 'MISC')]
# [('Frankfurt', 'LOC')]
# [('Der Mann mit dem Schild', 'MISC'), ('Einsatzwägen', 'LOC'), ('Humboldthain', 'LOC')]
# [('Anthony Fauci', 'PER'), ('Times Nachrichten', 'MISC')]

# %%
display_entities(samples)
# Out:
# /Users/elisabeth/repos/NER-german-telegram/venv/lib/python3.9/site-packages/spacy/displacy/__init__.py:205: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   warnings.warn(Warnings.W006)
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Freiburg </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Aufzug mit
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Endkundgebung
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  am Platz der
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     alten Synagoge
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Live Musik ! </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Details 19062021 Raus auf die Straße</div></span>
# ++++++++++++
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     GEHT DEMONSTRIEREN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  ! </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">- Message von
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Elijah Tee
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  an die
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dresdner &amp;
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  anderen Demonstranten in
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Deutschland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Morgen am 13.06. um 16.30 Uhr und bundesweit überall , wo es Mitdenker gibt . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">- Bilder und
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Videos
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  hochladen - Diskussion </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Fahren oder Mitfahren</div></span>
# ++++++++++++
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">15831
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Blankenfelde Mahlow
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Berliner
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  Speckgürtel </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Ausfahrt Lichtenrade am 14.03.2021 14032021 Raus auf die Straße</div></span>
# ++++++++++++
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">2021 10 11 </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sven Liebich
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  fragt Ministerpräsident
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Haseloff
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  nach dessen Verständnis von
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Versammlungsfre
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  — </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sven Liebich
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  0:23 Raus auf die Straßen   Übersicht / </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Overview</div></span>
# ++++++++++++
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">  FÜR </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">ALLE
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DEMOKRATEN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">  GEFAHR : Die Polizei blockiert den Stern ! </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">  </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Deswegen laufen die Menschen vom
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ernst-Reuther-Platz
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  nach Südosten zum
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Breitscheitplatz
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  und dort weiter auf den
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kudamm ! !
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Schließt euch an : </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Neue Kantstraße
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  direkt Richtung Osten auf den
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Breitscheitplatz
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  ! </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Von der Straße des 17. Juni Richtung Süden zum
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kudamm !
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# </div></span>
# ++++++++++++
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Dr.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gunter Frank
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  : Wie Moralismus dazu führt das man Feinde sieht und vernichten will —
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Antihygienista
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  -
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Offene Gesellschaft Kurpfalz
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  15:04 Raus auf die Straßen   Übersicht / </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Overview</div></span>
# ++++++++++++
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Einfach
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  nur Krank solche Politiker ! </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Was sollen wir mit ihm machen wenn unsere Kinder anhand dieser Impfung nen schaden erleiden ? </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Wer ist dann dafür verantwortlich , wen schmeißen wir dann in den Knast und nehmen sein ganzes Geld weg , sollen wir das mit dir machen ? </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Raus auf die Straße</div></span>
# ++++++++++++
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">27.11.2021 </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Frankfurt
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Durchsagen von gemischt mit Musik . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Super Idee </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">  </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Für mehr Berichte folgen auf ... </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Raus auf die Straßen   Übersicht / </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Overview</div></span>
# ++++++++++++
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">  Demo-Berlin :
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Der Mann mit dem Schild
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  wurde soeben von der Polizei festgenommen . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Circa 7
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Einsatzwägen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  sind vor Ort und umzäunen den Park großräumig . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Am
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Humboldthain
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  gibt es nichts mehr zu gewinnen . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr"># b2908 </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Raus auf die Straßen</div></span>
# ++++++++++++
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Anthony Fauci
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  : Definition von „ vollständig geimpft “ könnte geändert werden — Epoch
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Times Nachrichten
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  6:59 </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Raus auf die Straßen </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">  Übersicht / </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Overview</div></span>
# ++++++++++++

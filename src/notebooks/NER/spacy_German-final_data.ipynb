# %% [markdown]
# ## imports

# %%
import sys
sys.path.append('../../../NER-german-telegram')

import pandas as pd
from datetime import datetime
from random import sample

import spacy
from spacy import displacy

# %% [markdown]
# ## load data

# %%
file_name = '../../../data/data_for_annotation_2022_06_27.csv'

# %%
data = pd.read_csv(file_name)

# %%
df = data.copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3634 entries, 0 to 3633
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    3634 non-null   int64
#  1   id            3634 non-null   object
#  2   message_id    3634 non-null   int64
#  3   date          3634 non-null   object
#  4   cleaned_text  3634 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 142.1+ KB

# %% [markdown]
# ## select some sample texts

# %%
samples = df.cleaned_text.sample(20, random_state=42)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'message_id', 'date', 'cleaned_text'], dtype='object')

# %% [markdown]
# # Spacy

# %% [markdown]
# ## load model

# %%
nlp = spacy.load("de_core_news_md")

# %%
def get_entities(texts): 

    for text in texts: 
        
        entities = {}
        
        try: 
            doc = nlp(text)
            
            if doc.ents:
                print([(ent.text, ent.label_) for ent in doc.ents])
    
        except: 
            pass

# %%
def display_entities(texts):
    
    for text in texts: 
    
        try: 
            doc = nlp(text)
            sentence_spans = list(doc.sents)
            displacy.render(sentence_spans, style="ent")

        except:
            pass

# %%
get_entities(samples)
# Out:
# [('Aufgewacht Hildesheim', 'LOC'), ('Hildesheim an der Lilie', 'LOC'), ('@NiedersachsenInfoChat @Demotermine', 'LOC'), ('Videos', 'MISC'), ('@DemotermineChat', 'MISC')]
# [('München', 'LOC')]
# [('9.10.2021 Nürnberg', 'ORG'), ('Maske', 'ORG'), ('SPD', 'ORG'), ('MediaInformationCenter', 'MISC')]
# [('Apolda', 'LOC'), ('Bad Homburg', 'LOC'), ('Bottrop', 'LOC'), ('Celle', 'LOC'), ('Gerolstein', 'LOC'), ('Hanau', 'LOC'), ('Kaufbeuren-Neugablonz', 'LOC'), ('Kempten', 'LOC'), ('Allgäu', 'LOC'), ('Mühlhausen', 'LOC'), ('Neubrandenburg', 'LOC'), ('Nürnberg', 'LOC'), ('Nürnberg', 'LOC'), ('Rostock', 'LOC'), ('Rostock', 'LOC'), ('Schwandorf', 'LOC'), ('Haselbach', 'LOC'), ('Wilhelmshaven', 'LOC'), ('Zittau', 'LOC'), ('https://t.me/Demotermine/25211', 'MISC')]
# ...

# %%
display_entities(samples)
# Out:
# /Users/elisabeth/repos/NER-german-telegram/venv/lib/python3.9/site-packages/spacy/displacy/__init__.py:205: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   warnings.warn(Warnings.W006)
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Organisation :
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Aufgewacht Hildesheim
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Ort :
# ...

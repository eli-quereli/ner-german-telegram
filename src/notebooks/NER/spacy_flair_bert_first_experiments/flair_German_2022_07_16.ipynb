# %% [markdown]
# # Exploration of German-language Flair model for NER in Telegram messages

# %% [markdown]
# ## Imports

# %%
import pandas as pd
from flair.data import Sentence
from flair.models import SequenceTagger

# %% [markdown]
# ## Load data

# %% [markdown]
# Using 10 example texts selected from Telegram channels 'Demotermine' for first German-language NER experiments and for machine translation experiments.

# %%
file_name = '../../temp/translations_2022_06_09-2.csv'
data = pd.read_csv(file_name)

# %%
len(data)
# Out:
# 10

# %% [markdown]
# ## Select cleaned texts as sample

# %%
samples = df.cleaned_text
samples[0]
# Out:
# 'Freiburg Aufzug mit Endkundgebung am Platz der alten Synagoge . Live Musik ! Details 19062021 Raus auf die Straße'

# %% [markdown]
# ## Load Flair sequence tagger

# %%
tagger_default = SequenceTagger.load("flair/ner-german")
# Out:
# 2022-07-16 10:47:59,867 loading file /Users/elisabeth/.flair/models/ner-german/a125be40445295f7e94d0afdb742cc9ac40ec4e93259dc30f35220ffad9bf1f6.f46c4c5cfa5e34baa838983373e30051cd1cf1e933499408a49e451e784b0a11
# 2022-07-16 10:48:12,889 SequenceTagger predicts: Dictionary with 20 tags: <unk>, O, B-PER, E-PER, S-LOC, B-MISC, I-MISC, E-MISC, S-PER, B-ORG, E-ORG, S-ORG, I-ORG, B-LOC, E-LOC, S-MISC, I-PER, I-LOC, <START>, <STOP>

# %% [markdown]
# ## Methods to obtain and print entities in texts

# %%
from flair.data import Sentence
from flair.models import SequenceTagger

tagger_default = SequenceTagger.load("flair/ner-german")

def get_ents(tagger, text):

    sentence = Sentence(text)

    # predict NER tags
    tagger.predict(sentence)

    # print sentence
    print(sentence)

    # print predicted NER spans
    print('The following NER tags are found:')
    
    # iterate over entities and print
    for entity in sentence.get_spans('ner'):
        print(entity)
        
        
for text in samples:
    try:
        get_ents(tagger_default, text)
    except:
        pass

# %% [markdown]
# ## Execute

# %%
for text in samples:
    try:
        get_ents(tagger_default, text)
    except:
        pass
# Out:
# Sentence: "Freiburg Aufzug mit Endkundgebung am Platz der alten Synagoge . Live Musik ! Details 19062021 Raus auf die Straße" → ["Freiburg"/LOC]
# The following NER tags are found:
# Span[0:1]: "Freiburg" → LOC (0.8942)
# Sentence: "GEHT DEMONSTRIEREN ! - Message von Elijah Tee an die Dresdner & anderen Demonstranten in Deutschland Morgen am 13.06 . um 16.30 Uhr und bundesweit überall , wo es Mitdenker gibt . - Bilder und Videos hochladen - Diskussion Fahren oder Mitfahren" → ["Elijah Tee"/PER, "Deutschland"/LOC]
# The following NER tags are found:
# Span[6:8]: "Elijah Tee" → PER (0.996)
# Span[15:16]: "Deutschland" → LOC (0.9979)
# Sentence: "15831 Blankenfelde Mahlow Berliner Speckgürtel Ausfahrt Lichtenrade am 14.03.2021 14032021 Raus auf die Straße" → ["Blankenfelde Mahlow"/LOC, "Lichtenrade"/LOC]
# The following NER tags are found:
# Span[1:3]: "Blankenfelde Mahlow" → LOC (0.7538)
# Span[6:7]: "Lichtenrade" → LOC (0.9899)
# Sentence: "2021 10 11 Sven Liebich fragt Ministerpräsident Haseloff nach dessen Verständnis von Versammlungsfre — Sven Liebich 0:23 Raus auf die Straßen U ̈ bersicht / Overview" → ["Sven Liebich"/PER, "Haseloff"/PER, "Sven Liebich"/PER]
# The following NER tags are found:
# Span[3:5]: "Sven Liebich" → PER (0.9995)
# Span[7:8]: "Haseloff" → PER (0.999)
# Span[14:16]: "Sven Liebich" → PER (0.9998)
# Sentence: "FU ̈ R ALLE DEMOKRATEN GEFAHR : Die Polizei blockiert den Stern ! Deswegen laufen die Menschen vom Ernst-Reuther-Platz nach Südosten zum Breitscheitplatz und dort weiter auf den Kudamm ! ! Schließt euch an : Neue Kantstraße direkt Richtung Osten auf den Breitscheitplatz ! Von der Straße des 17. Juni Richtung Süden zum Kudamm !" → ["FU"/ORG, "Ernst-Reuther-Platz"/LOC, "Breitscheitplatz"/LOC, "Kudamm"/LOC, "Kantstraße"/LOC, "Breitscheitplatz"/LOC, "Kudamm"/LOC]
# The following NER tags are found:
# Span[0:1]: "FU" → ORG (0.998)
# Span[18:19]: "Ernst-Reuther-Platz" → LOC (0.9969)
# Span[22:23]: "Breitscheitplatz" → LOC (0.9985)
# Span[28:29]: "Kudamm" → LOC (0.9594)
# Span[36:37]: "Kantstraße" → LOC (0.9645)
# Span[42:43]: "Breitscheitplatz" → LOC (0.9961)
# Span[53:54]: "Kudamm" → LOC (0.9666)
# Sentence: "Dr. Gunter Frank : Wie Moralismus dazu führt das man Feinde sieht und vernichten will — Antihygienista - Offene Gesellschaft Kurpfalz 15:04 Raus auf die Straßen U ̈ bersicht / Overview" → ["Gunter Frank"/PER, "Antihygienista"/ORG, "Offene Gesellschaft Kurpfalz"/ORG]
# The following NER tags are found:
# Span[1:3]: "Gunter Frank" → PER (0.9997)
# Span[16:17]: "Antihygienista" → ORG (0.6492)
# Span[18:21]: "Offene Gesellschaft Kurpfalz" → ORG (0.8897)
# Sentence: "Einfach nur Krank solche Politiker ! Was sollen wir mit ihm machen wenn unsere Kinder anhand dieser Impfung nen schaden erleiden ? Wer ist dann dafür verantwortlich , wen schmeißen wir dann in den Knast und nehmen sein ganzes Geld weg , sollen wir das mit dir machen ? Raus auf die Straße"
# The following NER tags are found:
# Sentence: "27.11.2021 Frankfurt Durchsagen von gemischt mit Musik . Super Idee Für mehr Berichte folgen auf ... Raus auf die Straßen U ̈ bersicht / Overview" → ["Frankfurt"/LOC]
# The following NER tags are found:
# Span[1:2]: "Frankfurt" → LOC (0.9113)
# Sentence: "Demo-Berlin : Der Mann mit dem Schild wurde soeben von der Polizei festgenommen . Circa 7 Einsatzwägen sind vor Ort und umzäunen den Park großräumig . Am Humboldthain gibt es nichts mehr zu gewinnen . # b2908 Raus auf die Straßen" → ["Demo-Berlin"/LOC, "Humboldthain"/LOC]
# The following NER tags are found:
# Span[0:1]: "Demo-Berlin" → LOC (0.5906)
# Span[27:28]: "Humboldthain" → LOC (0.9717)
# Sentence: "Anthony Fauci : Definition von „ vollständig geimpft “ könnte geändert werden — Epoch Times Nachrichten 6:59 Raus auf die Straßen U ̈ bersicht / Overview" → ["Anthony Fauci"/PER, "Epoch Times Nachrichten"/ORG]
# The following NER tags are found:
# Span[0:2]: "Anthony Fauci" → PER (0.9997)
# Span[13:16]: "Epoch Times Nachrichten" → ORG (0.8771)
